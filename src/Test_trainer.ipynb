# %%
# !cd  '../datasets/agnews/' && rm *.pt

# %%
file = open('../datasets/agnews/train.txt', encoding='utf-8')

# %%
import torch
data = torch.load('../datasets/agnews/train.pt')

# %%
120000/5794
# Out:
# 20.711080428028996

# %%
from new_trainer import ClassifTrainer

# %%
# !cd .. && python3 src/test_train.py
# Out:
# 2021-01-25 16:15:36.560026: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# args Namespace(accum_steps=8, category_vocab_size=100, dataset_dir='datasets/agnews/', dist_port=12345, early_stop=False, eval_batch_size=32, final_model='final_model.pt', gpus=1, label_names_file='label_names_1.txt', loop_over_vocab=2, match_threshold=20, max_len=200, mcp_epochs=3, out_file='out.txt', self_train_epochs=1, test_file='test.txt', test_label_file='test_labels.txt', top_pred_num=50, train_batch_size=16, train_file='train.txt', train_label_file='train_labels.txt', true_label='2', update_interval=50)
# Effective training batch size: 128
# ['positive\n']
# Label names used for each class are: {0: ['business']}
# Label names positivity is: {0: 1, 1: 0}
# ...

# %%
dico = { 'a' : [1,2], 'b'  : [ 3,4]}

b = torch.tensor([[1,2],[3,4],[5,6]]).tolist()
torch.stack([torch.tensor(b[i]) for i in [0,2]]).size()
# Out:
# torch.Size([2, 2])

# %%
torch.tensor([[1,2],[3,4],[5,6]]).size()
# Out:
# torch.Size([3, 2])

# %%
b[2,3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-117-89da31643e69> in <module>
# ----> 1 b[2,3]
#
# TypeError: list indices must be integers or slices, not tuple
